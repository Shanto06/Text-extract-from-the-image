# %%
import pytesseract
import shutil
import os
import random
try:
    from PIL import Image
except ImportError:
    import Image

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-919e3527-c1f3-4818-bf10-e213db9818ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-919e3527-c1f3-4818-bf10-e213db9818ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pdf.jpg to pdf.jpg

# %%
extractedInformation = pytesseract.image_to_string(Image.open('pdf.jpg'))

# %%
extractedInformation.split('\n')
# Out:
# ['import pyttsx3',
#  '',
#  'import PyPDF2',
#  '',
#  'from tkinter.filedialog import *',
#  '',
#  'book = askopenfilename() #select the pdf file',
#  'pdfreader = PyPDF2.PdfFileReader (book)',
#  '',
#  'pages = pdfreader.numPages',
#  '',
#  'for number in range(1,pages):',
#  'page = pdfreader. getPage(number)',
#  'text = page.extractText()',
#  'player = pyttsx3.init()',
#  'player. say (text)',
#  'player .runandwait()',
#  '',
#  ' ',
#  '\x0c']

# %%
#!sudo apt install tesseract-ocr
#!pip install pytesseract
